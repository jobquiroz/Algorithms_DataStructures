# %% [markdown]
# ### Remove nth node from end of list
#
# Given the `head` of a linked list, remove the nth node from the end of the list and return its head.
#
# **Follow up**: Could you do this in one pass?
#
#
# **Example 1:**
# ![image.png](attachment:image.png)
#
# ```
# Input: head = [1,2,3,4,5], n = 2
# Output: [1,2,3,5]
# ```
#
#
# **Example 2:**
# ```
# Input: head = [1], n = 1
# Output: []
# ```
#
# **Example 3:**
# ```
# Input: head = [1,2], n = 1
# Output: [1]
# ```
#
# #### Constraints:
#
# - The number of nodes in the list is `sz`.
# - `1 <= sz <= 30`
# - `0 <= Node.val <= 100`
# - `1 <= n <= sz`

# %% [markdown]
# ### Naive solution

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def is_nth(head: ListNode, n:int):
    aux = head
    for i in range(1, n+1):
        if aux.next == None:
            return i >= n
        else:
            aux = aux.next
    return False
        
def removeNthFromEnd(head: ListNode, n: int) -> ListNode:
    if is_nth(head, n):
        return head.next
    else:
        prev = head
        current = head.next
        while current:
            if is_nth(current, n):
                prev.next = current.next
                return head
            else:
                prev = current
                current = current.next
        if n == 1:
            return None

# %% [markdown]
# ### Great!
#
# ![image.png](attachment:image.png)

# %%
#head = [1,2,3,4,5]
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(5)

# %%
print(is_nth(head, 5))
# Out:
# True

# %%
while head != None:
    print(head.val)
    head = head.next
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
is_nth(head, n)

# %%
#head = [1,2,3,4,5]
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(5)

head = removeNthFromEnd(head, 1)

while head != None:
    print(head.val)
    head = head.next
# Out:
# 1
# 2
# 3
# 4

# %% [markdown]
# ## Instructor's solution

# %%
# Definition for singly-linked list.
class ListNode:
    def __init__(self, val=0, next=None):
        self.val = val
        self.next = next

def removeNthFromEnd(head: ListNode, n: int) -> ListNode:
    # 1. Measure length
    on = head
    length = 1
    
    while on:
        length += 1
        on = on.next
    
    leftIndex = length - n - 1
    
    # 1.5 handle head deletion (edge case)
    if leftIndex == 0:
        return head.next
    
    # 2. point around node n
    on = head
    while leftIndex > 1:
        leftIndex -= 1
        on = on.next
    
    on.next = on.next.next
    
    return head

# %%
#head = [1,2,3,4,5]
head = ListNode(1)
head.next = ListNode(2)
head.next.next = ListNode(3)
head.next.next.next = ListNode(4)
head.next.next.next.next = ListNode(5)

head = removeNthFromEnd(head, 2)

while head != None:
    print(head.val)
    head = head.next
# Out:
# 1
# 2
# 3
# 5

# %% [markdown]
# ### Nice

# %% [markdown]
# ![image.png](attachment:image.png)
